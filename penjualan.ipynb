# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("penjualan.csv")

data.head()
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tanggal       75 non-null     object
#  1   Produk        75 non-null     object
#  2   Jumlah        75 non-null     int64
#  3   Harga_Satuan  75 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 2.5+ KB
#           Jumlah   Harga_Satuan
# count  75.000000      75.000000
# mean    2.400000  170133.333333
# std     1.325427  102752.567316
# min     1.000000   50000.000000
# 25%     1.000000  100000.000000
# 50%     2.000000  120000.000000
# 75%     3.000000  250000.000000
# max     6.000000  400000.000000

# %%
data['Tanggal'] = pd.to_datetime(data['Tanggal'])

# %% [markdown]
# Tugasnya adalah:
#
# 📥 Baca file penjualan.csv ke pandas
# ➗ Hitung kolom Total_Penjualan = Jumlah * Harga_Satuan
# 📊 Group by Produk → total jumlah terjual & pendapatan
# 📈 Visualisasi bar chart penjualan
# 🧠 Insight akhir
# 💾 Simpan hasil ke CSV
# ✍️ Perbaiki README.md dan upload ke GitHub

# %%
data['Total_Penjualan']= data['Jumlah']*data['Harga_Satuan']

data.head()
# Out:
#      Tanggal  Produk  Jumlah  Harga_Satuan  Total Penjualan  Total_Penjualan
# 0 2025-06-01    Baju       5        100000           500000           500000
# 1 2025-06-01  Celana       3        120000           360000           360000
# 2 2025-06-01  Sepatu       2        250000           500000           500000
# 3 2025-06-01    Topi       4         50000           200000           200000
# 4 2025-06-01   Jaket       1        300000           300000           300000

# %%
# Total penjualan tiap produk
penjualan_per_produk = data.groupby('Produk')['Total_Penjualan'].sum().sort_values(ascending=False)
print(penjualan_per_produk)
# Out:
# Produk
# Baju          5400000
# Sepatu        3750000
# Celana        3720000
# Tas           3200000
# Jaket         3000000
# Jam Tangan    2800000
# Topi          2000000
# Kacamata      1050000
# Name: Total_Penjualan, dtype: int64

# %%
jumlah_terjual = data.groupby('Produk')['Jumlah'].sum().sort_values(ascending=False)
print(jumlah_terjual)
# Out:
# Produk
# Baju          54
# Topi          40
# Celana        31
# Tas           16
# Sepatu        15
# Jaket         10
# Jam Tangan     7
# Kacamata       7
# Name: Jumlah, dtype: int64

# %%
penjualan_per_produk.plot(kind='bar', color='skyblue', figsize=(10, 5))
plt.title('Total Pendapatan per Produk')
plt.ylabel('Total (Rp)')
plt.xlabel('Produk')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
jumlah_terjual.plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8), startangle=90)
plt.title('Distribusi Jumlah Barang Terjual per Produk')
plt.ylabel('')
plt.show()

# %% [markdown]
# # 📌 Insight
#
# - Produk dengan total penjualan terbesar adalah **Baju**. Selain paling menguntungkan, produk ini juga menjadi barang yang **paling laris**.
# - Produk dengan harga mahal seperti **Jam Tangan** ternyata memiliki volume penjualan rendah, termasuk dalam **tiga produk paling sedikit terjual**.
# - Berdasarkan pola ini, disarankan agar toko lebih memfokuskan strategi penjualan pada produk-produk yang **tinggi permintaan namun tetap menguntungkan**, yaitu: **Baju**, **Topi**, dan **Celana**.
